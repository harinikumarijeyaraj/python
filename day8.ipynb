# %%
t=(1,2,3,4,6)
l=list(t)
l[2]=7
t=tuple(l)
t
# Out:
# (1, 2, 7, 4, 6)

# %%
veg = ("apple", "banana", "cherry")

(green, yellow, red) = veg

print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# cherry

# %%
mytuple = (1, 3, 7, 8, 7, 5, 4, 6, 8, 5)
list1=list(mytuple)
list1.append("hi")
mytuple=tuple(list1)
mytuple
# Out:
# (1, 3, 7, 8, 7, 5, 4, 6, 8, 5, 'hi')
