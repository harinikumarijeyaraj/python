# %%
l = {"apple", "banana", "cherry"}
l1 = {"pineapple", "mango", "papaya"}

l.update(l1)

print(l)
# Out:
# {'banana', 'papaya', 'cherry', 'mango', 'apple', 'pineapple'}

# %%
l = { "banana","apple","hji",9,78,"hello"}
print(l)
x = l.pop()

print(x)
# Out:
# {'banana', 'hji', 9, 'apple', 78, 'hello'}
# banana
