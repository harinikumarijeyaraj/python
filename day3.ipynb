# %%
a=54
b=47
h= (a/b)
print(h)
# Out:
# 1.148936170212766

# %%
a=54
b=47
h=(a//b)
print(h)
# Out:
# 1

# %%
a=54
b=47
h=(a%b)
print(h)
# Out:
# 7

# %%
a=5
b=3
h=(a**b)
print(h)
# Out:
# 125

# %%
a=785
b=853
h=(a*b)
print(h)
# Out:
# 669605

# %%
a=65
b=98
h=(a<b)
print (h)
# Out:
# True

# %%
a=65
b=98
h=(a>b)
print(h)
# Out:
# False

# %%
a=65
b=54
a=a+b
print(a)
# Out:
# 119
